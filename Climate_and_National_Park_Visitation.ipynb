# %% [markdown]
# # Master Branch Code
#
# ## How does the climate impact visitation to the U.S. National Parks?
#
# ### Hypothesis: Increasing average annual temperature has a positive correlation with the total number of registered visitors to the U.S. National Parks annually.
#
# #### Team Members: Andy Swellie, Nick Marchetti, Tony "The IT Guy" Elkadi, Kevin Coyne

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import os
from pprint import pprint
import csv
import gmaps
import datetime

# %% [markdown]
# ### Get Latitude and Longitude for 20 most visited parks - Anthony
# #### Need to put the API key into a config file and replace that in the URL string

# %%
top_20_parks = ["Great Smoky Mountains National Park", "Grand Canyon National Park", "Yosemite National Park", 
                "Rocky Mountain National Park", "Zion National Park", "Yellowstone National Park", "Olympic National Park", 
                "Acadia National Park", "Grand Teton National Park", "Glacier National Park", "Joshua Tree National Park", 
               "Cuyahoga Valley National Park", "Bryce Canyon", "Hawaii Volcanoes National Park", "Arches National Park", "Hot Springs National Park",
                "Shannondoah National Park", "Mount Rainier National Park", "Death Valley National Park", "Halekala National Park"]

lats = []
lngs = []
parks = []


for park in top_20_parks:
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=" + park + "&inputtype=textquery&fields=name,geometry&key=AIzaSyAfjVUQRwNEoYjUpjNsyAL5Nc8is2IUykg"
    response = requests.get(url)
    national_park_json = response.json()
    
    lats.append(national_park_json["candidates"][0]["geometry"]["location"]["lat"])
    lngs.append(national_park_json["candidates"][0]["geometry"]["location"]["lng"])
    parks.append(park)

columns = ["Park", "Lat", "Lng"]
National_Parks_df = pd.DataFrame(columns=columns)
National_Parks_df["Park"] = parks
National_Parks_df["Lat"] = lats
National_Parks_df["Lng"] = lngs
National_Parks_df.head(20)
# Out:
#                                    Park        Lat         Lng
# 0   Great Smoky Mountains National Park  35.611764  -83.489545
# 1            Grand Canyon National Park  36.106965 -112.112997
# 2                Yosemite National Park  37.865101 -119.538329
# 3          Rocky Mountain National Park  40.342793 -105.683639
# 4                    Zion National Park  37.298202 -113.026301
# 5             Yellowstone National Park  44.427963 -110.588455
# 6                 Olympic National Park  47.802107 -123.604352
# 7                  Acadia National Park  44.338556  -68.273335
# 8             Grand Teton National Park  43.790428 -110.681763
# 9                 Glacier National Park  48.759613 -113.787023
# 10            Joshua Tree National Park  33.873415 -115.900992
# 11        Cuyahoga Valley National Park  41.280825  -81.567812
# 12                         Bryce Canyon  37.593038 -112.187089
# 13       Hawaii Volcanoes National Park  19.419370 -155.288497
# 14                 Arches National Park  38.733081 -109.592514
# 15            Hot Springs National Park  34.521692  -93.042355
# 16            Shannondoah National Park  38.292756  -78.679584
# 17          Mount Rainier National Park  46.879966 -121.726909
# 18           Death Valley National Park  36.505389 -117.079408
# 19               Halekala National Park  20.709692 -156.253515

# %%
National_Parks_df.to_csv("Top_20_Parks.csv", index=False, header=True)

# %%
# Take top 20 most visited National Parks in the US

top_20_parks = ["Great Smoky Mountains National Park", "Grand Canyon National Park", "Yosemite National Park", 
                "Rocky Mountain National Park", "Zion National Park", "Yellowstone National Park", "Olympic National Park", 
                "Acadia National Park", "Grand Teton National Park", "Glacier National Park", "Joshua Tree National Park", 
               "Cuyahoga Valley National Park", "Bryce Canyon", "Hawaii Volcanoes National Park", "Arches National Park", "Hot Springs National Park",
                "Shannondoah National Park", "Mount Rainier National Park", "Death Valley National Park", "Halekala National Park"]

# Plot Heatmap

fig = gmaps.figure()

# Define locations
locations = National_Parks_df[["Lat", "Lng"]]

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Pull in CSV files of visitor data by park and build data frames - Andy
#
# #### Park visit data was pulled down and converted to CSV using a google widget from: "https://irma.nps.gov/Stats/SSRSReports/Park%20Specific%20Reports/Visitation%20by%20Month?Park=SAJU"

# %%
park_visits = "Top10_Parks_Visits/Top10_Park_Visits.csv"
park_visits_df = pd.read_csv(park_visits, encoding="utf-8")

park_visits_df.head(3000)
# Out:
#                       Park  Year  Month  Visits
# 0     Acadia National Park  2018      1   11974
# 1     Acadia National Park  2018      2   12167
# 2     Acadia National Park  2018      3   23756
# 3     Acadia National Park  2018      4   72858
# 4     Acadia National Park  2018      5  249050
# 5     Acadia National Park  2018      6  499163
# 6     Acadia National Park  2018      7  759165
# 7     Acadia National Park  2018      8  767219
# 8     Acadia National Park  2018      9  600397
# 9     Acadia National Park  2018     10  488204
# 10    Acadia National Park  2018     11   40930
# 11    Acadia National Park  2018     12   12692
# 12    Acadia National Park  2017      1   15520
# 13    Acadia National Park  2017      2   14342
# 14    Acadia National Park  2017      3   20936
# 15    Acadia National Park  2017      4   85267
# 16    Acadia National Park  2017      5  222978
# 17    Acadia National Park  2017      6  476191
# 18    Acadia National Park  2017      7  743529
# 19    Acadia National Park  2017      8  762436
# 20    Acadia National Park  2017      9  595388
# 21    Acadia National Park  2017     10  507594
# 22    Acadia National Park  2017     11   53006
# 23    Acadia National Park  2017     12   12084
# 24    Acadia National Park  2016      1   17204
# 25    Acadia National Park  2016      2   16530
# 26    Acadia National Park  2016      3   28121
# 27    Acadia National Park  2016      4   94199
# 28    Acadia National Park  2016      5  217147
# 29    Acadia National Park  2016      6  445410
# ...                    ...   ...    ...     ...
# 1170    Zion National Park  2011      7  391144
# 1171    Zion National Park  2011      8  360196
# 1172    Zion National Park  2011      9  324727
# 1173    Zion National Park  2011     10  273876
# 1174    Zion National Park  2011     11  145158
# 1175    Zion National Park  2011     12   76687
# 1176    Zion National Park  2010      1   54928
# 1177    Zion National Park  2010      2   62099
# 1178    Zion National Park  2010      3  171079
# 1179    Zion National Park  2010      4  277599
# 1180    Zion National Park  2010      5  304278
# 1181    Zion National Park  2010      6  331185
# 1182    Zion National Park  2010      7  362881
# 1183    Zion National Park  2010      8  332796
# 1184    Zion National Park  2010      9  319838
# 1185    Zion National Park  2010     10  236316
# 1186    Zion National Park  2010     11  143272
# 1187    Zion National Park  2010     12   69701
# 1188    Zion National Park  2009      1   60204
# 1189    Zion National Park  2009      2   62964
# 1190    Zion National Park  2009      3  167246
# 1191    Zion National Park  2009      4  271709
# 1192    Zion National Park  2009      5  296330
# 1193    Zion National Park  2009      6  366004
# 1194    Zion National Park  2009      7  368933
# 1195    Zion National Park  2009      8  372157
# 1196    Zion National Park  2009      9  306161
# 1197    Zion National Park  2009     10  265095
# 1198    Zion National Park  2009     11  132998
# 1199    Zion National Park  2009     12   65601
#
# [1200 rows x 4 columns]

# %% [markdown]
# ### Create a list of dates to use in the weather API calls - Nick

# %%
base_url = "https://api.darksky.net/forecast/[key]/[latitude],[longitude]"

url = "https://api.darksky.net/forecast/207521500b0c1207a0cd6d1181bf4ce1/40.5,-80.7,2010-06-01T12:00:00"

# %%
response = requests.get(url)
json_response = response.json()
print(response)
# Out:
# <Response [200]>

# %%
pprint(json_response)
# Out:
# {'currently': {'apparentTemperature': 73.98,
#                'cloudCover': 1,
#                'dewPoint': 63.01,
#                'humidity': 0.69,
#                'icon': 'cloudy',
#                'precipIntensity': 0,
#                'precipProbability': 0,
#                'pressure': 1013.64,
#                'summary': 'Overcast',
#                'temperature': 73.66,
#                'time': 1275408000,
#                'uvIndex': 4,
#                'visibility': 2.55,
#                'windBearing': 277,
#                'windGust': 6.24,
#                'windSpeed': 2.33},
#  'daily': {'data': [{'apparentTemperatureHigh': 79.27,
#                      'apparentTemperatureHighTime': 1275429600,
#                      'apparentTemperatureLow': 57.65,
#                      'apparentTemperatureLowTime': 1275472800,
#                      'apparentTemperatureMax': 79.27,
#                      'apparentTemperatureMaxTime': 1275429600,
#                      'apparentTemperatureMin': 64.18,
#                      'apparentTemperatureMinTime': 1275447600,
#                      'cloudCover': 0.67,
#                      'dewPoint': 63.51,
#                      'humidity': 0.79,
#                      'icon': 'fog',
#                      'moonPhase': 0.65,
#                      'precipIntensity': 0.0006,
#                      'precipIntensityMax': 0.0091,
#                      'precipIntensityMaxTime': 1275368400,
#                      'precipProbability': 0.3,
#                      'precipType': 'rain',
#                      'pressure': 1012.28,
#                      'summary': 'Foggy in the morning.',
#                      'sunriseTime': 1275386156,
#                      'sunsetTime': 1275439703,
#                      'temperatureHigh': 79.1,
#                      'temperatureHighTime': 1275429600,
#                      'temperatureLow': 57.65,
#                      'temperatureLowTime': 1275472800,
#                      'temperatureMax': 79.1,
#                      'temperatureMaxTime': 1275429600,
#                      'temperatureMin': 63.99,
#                      'temperatureMinTime': 1275447600,
#                      'time': 1275364800,
#                      'uvIndex': 6,
#                      'uvIndexTime': 1275411600,
#                      'visibility': 2.22,
#                      'windBearing': 276,
#                      'windGust': 8.44,
#                      'windGustTime': 1275415200,
#                      'windSpeed': 1.49}]},
#  'flags': {'nearest-station': 2.367,
#            'sources': ['cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 68.6,
#                       'cloudCover': 0.85,
#                       'dewPoint': 65.65,
#                       'humidity': 0.93,
#                       'icon': 'fog',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.29,
#                       'summary': 'Foggy',
#                       'temperature': 67.75,
#                       'time': 1275364800,
#                       'uvIndex': 0,
#                       'visibility': 1.67,
#                       'windBearing': 199,
#                       'windGust': 6.48,
#                       'windSpeed': 0.51},
#                      {'apparentTemperature': 67.48,
#                       'cloudCover': 0.41,
#                       'dewPoint': 64.51,
#                       'humidity': 0.93,
#                       'icon': 'fog',
#                       'precipIntensity': 0.0091,
#                       'precipProbability': 0.3,
#                       'precipType': 'rain',
#                       'pressure': 1011.22,
#                       'summary': 'Foggy',
#                       'temperature': 66.75,
#                       'time': 1275368400,
#                       'uvIndex': 0,
#                       'visibility': 1.27,
#                       'windBearing': 157,
#                       'windGust': 5.54,
#                       'windSpeed': 0.51},
#                      {'apparentTemperature': 67.36,
#                       'cloudCover': 0.57,
#                       'dewPoint': 64.94,
#                       'humidity': 0.95,
#                       'icon': 'fog',
#                       'precipIntensity': 0.0032,
#                       'precipProbability': 0.13,
#                       'precipType': 'rain',
#                       'pressure': 1010.6,
#                       'summary': 'Foggy',
#                       'temperature': 66.56,
#                       'time': 1275372000,
#                       'uvIndex': 0,
#                       'visibility': 1.58,
#                       'windBearing': 173,
#                       'windGust': 4.84,
#                       'windSpeed': 0.5},
#                      {'apparentTemperature': 67.89,
#                       'cloudCover': 0.75,
#                       'dewPoint': 66.07,
#                       'humidity': 0.97,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1010.68,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 66.93,
#                       'time': 1275375600,
#                       'uvIndex': 0,
#                       'visibility': 2.33,
#                       'windBearing': 223,
#                       'windGust': 3.18,
#                       'windSpeed': 0.68},
#                      {'apparentTemperature': 68.21,
#                       'cloudCover': 0.9,
#                       'dewPoint': 66.12,
#                       'humidity': 0.96,
#                       'icon': 'fog',
#                       'precipIntensity': 0.0005,
#                       'precipProbability': 0.14,
#                       'precipType': 'rain',
#                       'pressure': 1010.69,
#                       'summary': 'Foggy',
#                       'temperature': 67.27,
#                       'time': 1275379200,
#                       'uvIndex': 0,
#                       'visibility': 1.73,
#                       'windBearing': 258,
#                       'windGust': 3.96,
#                       'windSpeed': 1.82},
#                      {'apparentTemperature': 68.17,
#                       'cloudCover': 1,
#                       'dewPoint': 64.89,
#                       'humidity': 0.92,
#                       'icon': 'fog',
#                       'precipIntensity': 0.0004,
#                       'precipProbability': 0.07,
#                       'precipType': 'rain',
#                       'pressure': 1010.73,
#                       'summary': 'Foggy',
#                       'temperature': 67.42,
#                       'time': 1275382800,
#                       'uvIndex': 0,
#                       'visibility': 1.67,
#                       'windBearing': 264,
#                       'windGust': 4.63,
#                       'windSpeed': 1.22},
#                      {'apparentTemperature': 68.01,
#                       'cloudCover': 1,
#                       'dewPoint': 65.11,
#                       'humidity': 0.93,
#                       'icon': 'fog',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.19,
#                       'summary': 'Foggy',
#                       'temperature': 67.22,
#                       'time': 1275386400,
#                       'uvIndex': 0,
#                       'visibility': 1.94,
#                       'windBearing': 261,
#                       'windGust': 3.82,
#                       'windSpeed': 1.73},
#                      {'apparentTemperature': 67.53,
#                       'cloudCover': 1,
#                       'dewPoint': 65.27,
#                       'humidity': 0.95,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.96,
#                       'summary': 'Overcast',
#                       'temperature': 66.68,
#                       'time': 1275390000,
#                       'uvIndex': 0,
#                       'visibility': 2.23,
#                       'windBearing': 272,
#                       'windGust': 4.18,
#                       'windSpeed': 2.21},
#                      {'apparentTemperature': 67.52,
#                       'cloudCover': 1,
#                       'dewPoint': 65.1,
#                       'humidity': 0.95,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.62,
#                       'summary': 'Overcast',
#                       'temperature': 66.71,
#                       'time': 1275393600,
#                       'uvIndex': 1,
#                       'visibility': 2.04,
#                       'windBearing': 283,
#                       'windGust': 4.57,
#                       'windSpeed': 2.07},
#                      {'apparentTemperature': 68.92,
#                       'cloudCover': 1,
#                       'dewPoint': 64.61,
#                       'humidity': 0.88,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.26,
#                       'summary': 'Overcast',
#                       'temperature': 68.25,
#                       'time': 1275397200,
#                       'uvIndex': 2,
#                       'visibility': 2.16,
#                       'windBearing': 283,
#                       'windGust': 4.88,
#                       'windSpeed': 1.7},
#                      {'apparentTemperature': 71.09,
#                       'cloudCover': 1,
#                       'dewPoint': 65.42,
#                       'humidity': 0.84,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.47,
#                       'summary': 'Overcast',
#                       'temperature': 70.39,
#                       'time': 1275400800,
#                       'uvIndex': 3,
#                       'visibility': 2.29,
#                       'windBearing': 277,
#                       'windGust': 5.66,
#                       'windSpeed': 2.34},
#                      {'apparentTemperature': 72.32,
#                       'cloudCover': 0.75,
#                       'dewPoint': 63.85,
#                       'humidity': 0.76,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.46,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 71.87,
#                       'time': 1275404400,
#                       'uvIndex': 5,
#                       'visibility': 2.56,
#                       'windBearing': 288,
#                       'windGust': 6.1,
#                       'windSpeed': 2.73},
#                      {'apparentTemperature': 73.98,
#                       'cloudCover': 1,
#                       'dewPoint': 63.01,
#                       'humidity': 0.69,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.64,
#                       'summary': 'Overcast',
#                       'temperature': 73.66,
#                       'time': 1275408000,
#                       'uvIndex': 4,
#                       'visibility': 2.55,
#                       'windBearing': 277,
#                       'windGust': 6.24,
#                       'windSpeed': 2.33},
#                      {'apparentTemperature': 75.7,
#                       'cloudCover': 0.75,
#                       'dewPoint': 63.46,
#                       'humidity': 0.67,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.55,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 75.33,
#                       'time': 1275411600,
#                       'uvIndex': 6,
#                       'visibility': 2.55,
#                       'windBearing': 275,
#                       'windGust': 7.78,
#                       'windSpeed': 3.15},
#                      {'apparentTemperature': 77.34,
#                       'cloudCover': 0.75,
#                       'dewPoint': 63.59,
#                       'humidity': 0.63,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.33,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 76.96,
#                       'time': 1275415200,
#                       'uvIndex': 6,
#                       'visibility': 2.65,
#                       'windBearing': 291,
#                       'windGust': 8.44,
#                       'windSpeed': 2.9},
#                      {'apparentTemperature': 77.67,
#                       'cloudCover': 0.75,
#                       'dewPoint': 63.89,
#                       'humidity': 0.64,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.16,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 77.26,
#                       'time': 1275418800,
#                       'uvIndex': 5,
#                       'visibility': 2.56,
#                       'windBearing': 279,
#                       'windGust': 8.07,
#                       'windSpeed': 2.35},
#                      {'apparentTemperature': 78.08,
#                       'cloudCover': 0.75,
#                       'dewPoint': 61.64,
#                       'humidity': 0.57,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.7,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 77.89,
#                       'time': 1275422400,
#                       'uvIndex': 5,
#                       'visibility': 2.56,
#                       'windBearing': 276,
#                       'windGust': 8.1,
#                       'windSpeed': 2.79},
#                      {'apparentTemperature': 78.87,
#                       'cloudCover': 0.44,
#                       'dewPoint': 61.97,
#                       'humidity': 0.57,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 78.64,
#                       'time': 1275426000,
#                       'uvIndex': 4,
#                       'visibility': 2.42,
#                       'windBearing': 274,
#                       'windGust': 7.67,
#                       'windSpeed': 2.84},
#                      {'apparentTemperature': 79.27,
#                       'cloudCover': 0.44,
#                       'dewPoint': 61.22,
#                       'humidity': 0.54,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.04,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 79.1,
#                       'time': 1275429600,
#                       'uvIndex': 2,
#                       'visibility': 2.61,
#                       'windBearing': 307,
#                       'windGust': 7.53,
#                       'windSpeed': 1.92},
#                      {'apparentTemperature': 77.73,
#                       'cloudCover': 0.44,
#                       'dewPoint': 60.61,
#                       'humidity': 0.56,
#                       'icon': 'partly-cloudy-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1011.92,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 77.64,
#                       'time': 1275433200,
#                       'uvIndex': 1,
#                       'visibility': 2.56,
#                       'windBearing': 278,
#                       'windGust': 7.43,
#                       'windSpeed': 1.8},
#                      {'apparentTemperature': 75.19,
#                       'cloudCover': 0.19,
#                       'dewPoint': 61.12,
#                       'humidity': 0.62,
#                       'icon': 'clear-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.18,
#                       'summary': 'Clear',
#                       'temperature': 75.07,
#                       'time': 1275436800,
#                       'uvIndex': 0,
#                       'visibility': 2.56,
#                       'windBearing': 313,
#                       'windGust': 5.94,
#                       'windSpeed': 0.28},
#                      {'apparentTemperature': 69.76,
#                       'cloudCover': 0.19,
#                       'dewPoint': 61.15,
#                       'humidity': 0.75,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.47,
#                       'summary': 'Clear',
#                       'temperature': 69.59,
#                       'time': 1275440400,
#                       'uvIndex': 0,
#                       'visibility': 2.61,
#                       'windBearing': 270,
#                       'windGust': 5.38,
#                       'windSpeed': 0.01},
#                      {'apparentTemperature': 66.31,
#                       'cloudCover': 0.08,
#                       'dewPoint': 60.94,
#                       'humidity': 0.84,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.71,
#                       'summary': 'Clear',
#                       'temperature': 66.08,
#                       'time': 1275444000,
#                       'uvIndex': 0,
#                       'visibility': 2.17,
#                       'windGust': 4.86,
#                       'windSpeed': 0},
#                      {'apparentTemperature': 64.18,
#                       'cloudCover': 0.08,
#                       'dewPoint': 60.06,
#                       'humidity': 0.87,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1012.95,
#                       'summary': 'Clear',
#                       'temperature': 63.99,
#                       'time': 1275447600,
#                       'uvIndex': 0,
#                       'visibility': 2.04,
#                       'windGust': 6.06,
#                       'windSpeed': 0}],
#             'icon': 'fog',
#             'summary': 'Foggy until morning.'},
#  'latitude': 40.5,
#  'longitude': -80.7,
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %%
dates = pd.date_range(start='2008-01-01', end='2018-12-31', freq='2d')

print(dates)
# Out:
# DatetimeIndex(['2008-01-01', '2008-01-03', '2008-01-05', '2008-01-07',
#                '2008-01-09', '2008-01-11', '2008-01-13', '2008-01-15',
#                '2008-01-17', '2008-01-19',
#                ...
#                '2018-12-12', '2018-12-14', '2018-12-16', '2018-12-18',
#                '2018-12-20', '2018-12-22', '2018-12-24', '2018-12-26',
#                '2018-12-28', '2018-12-30'],
#               dtype='datetime64[ns]', length=2009, freq='2D')

# %%
url_dates = []
reg_dates = []
months = []
years = []

for x in dates:
    date_parts = datetime.datetime.strptime((str(x).split(' ', 1)[0]), "%Y-%m-%d")
    # month number
    months.append(date_parts.month)
    years.append(date_parts.year)
    reg_dates.append((str(x).split(' ', 1)[0]))
    url_dates.append((str(x).split(' ', 1)[0]) + "T12:00:00")

# %%
date_df = pd.DataFrame({"date" : reg_dates,
                        "url_date" : url_dates,
                        "year" : years,
                        "month" : months})

date_df.head()
# Out:
#          date             url_date  year  month
# 0  2008-01-01  2008-01-01T12:00:00  2008      1
# 1  2008-01-03  2008-01-03T12:00:00  2008      1
# 2  2008-01-05  2008-01-05T12:00:00  2008      1
# 3  2008-01-07  2008-01-07T12:00:00  2008      1
# 4  2008-01-09  2008-01-09T12:00:00  2008      1

# %% [markdown]
# ### Weather API calls & Data Frames - Kevin & Nick

# %%
base_url = "https://api.darksky.net/forecast/[key]/[latitude],[longitude]"
test_url = "https://api.darksky.net/forecast/207521500b0c1207a0cd6d1181bf4ce1/35.611764,-83.489545,2009-02-03T12:00:00"

file = "CSVs/Top_10_Parks.csv"

park_df = pd.read_csv(file)

park_df.head()
# Out:
#                                   Park        Lat         Lng
# 0  Great Smoky Mountains National Park  35.611764  -83.489545
# 1           Grand Canyon National Park  36.106965 -112.112997
# 2               Yosemite National Park  37.865101 -119.538329
# 3         Rocky Mountain National Park  40.342793 -105.683639
# 4                   Zion National Park  37.298202 -113.026300

# %%
response = requests.get(test_url)
json_response = response.json()
print(response)
# Out:
# <Response [200]>

# %%
pprint(json_response)
# Out:
# {'currently': {'apparentTemperature': 24.76,
#                'cloudCover': 1,
#                'dewPoint': 17.16,
#                'humidity': 0.72,
#                'icon': 'cloudy',
#                'precipIntensity': 0.0008,
#                'precipProbability': 0.22,
#                'precipType': 'snow',
#                'summary': 'Overcast',
#                'temperature': 24.76,
#                'time': 1233680400,
#                'uvIndex': 3,
#                'visibility': 10,
#                'windBearing': 250,
#                'windGust': 10.62,
#                'windSpeed': 2.34},
#  'daily': {'data': [{'apparentTemperatureHigh': 24.76,
#                      'apparentTemperatureHighTime': 1233680400,
#                      'apparentTemperatureLow': -6.2,
#                      'apparentTemperatureLowTime': 1233745200,
#                      'apparentTemperatureMax': 24.76,
#                      'apparentTemperatureMaxTime': 1233680400,
#                      'apparentTemperatureMin': -1.54,
#                      'apparentTemperatureMinTime': 1233716400,
#                      'cloudCover': 0.5,
#                      'dewPoint': 15.31,
#                      'humidity': 0.88,
#                      'icon': 'cloudy',
#                      'moonPhase': 0.28,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0.0008,
#                      'precipIntensityMaxTime': 1233680400,
#                      'precipProbability': 0,
#                      'summary': 'Overcast starting in the afternoon.',
#                      'sunriseTime': 1233664393,
#                      'sunsetTime': 1233702300,
#                      'temperatureHigh': 24.95,
#                      'temperatureHighTime': 1233691200,
#                      'temperatureLow': 0.44,
#                      'temperatureLowTime': 1233738000,
#                      'temperatureMax': 24.95,
#                      'temperatureMaxTime': 1233691200,
#                      'temperatureMin': 4.38,
#                      'temperatureMinTime': 1233720000,
#                      'time': 1233637200,
#                      'uvIndex': 3,
#                      'uvIndexTime': 1233676800,
#                      'visibility': 9.42,
#                      'windBearing': 288,
#                      'windGust': 16.03,
#                      'windGustTime': 1233709200,
#                      'windSpeed': 1.69}]},
#  'flags': {'nearest-station': 3.408,
#            'sources': ['cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 19.9,
#                       'cloudCover': 0,
#                       'dewPoint': 17.55,
#                       'humidity': 0.9,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 19.9,
#                       'time': 1233637200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 16,
#                       'windGust': 9.67,
#                       'windSpeed': 1.75},
#                      {'apparentTemperature': 19.78,
#                       'cloudCover': 0,
#                       'dewPoint': 17.53,
#                       'humidity': 0.91,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 19.78,
#                       'time': 1233640800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 1,
#                       'windGust': 11.67,
#                       'windSpeed': 2.03},
#                      {'apparentTemperature': 18.87,
#                       'cloudCover': 0,
#                       'dewPoint': 17.7,
#                       'humidity': 0.95,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 18.87,
#                       'time': 1233644400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 16,
#                       'windGust': 8.69,
#                       'windSpeed': 1.23},
#                      {'apparentTemperature': 17.76,
#                       'cloudCover': 0,
#                       'dewPoint': 16.74,
#                       'humidity': 0.96,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 17.76,
#                       'time': 1233648000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 7,
#                       'windGust': 12.96,
#                       'windSpeed': 2.92},
#                      {'apparentTemperature': 16.89,
#                       'cloudCover': 0,
#                       'dewPoint': 15.58,
#                       'humidity': 0.94,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 16.89,
#                       'time': 1233651600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 11,
#                       'windGust': 10.75,
#                       'windSpeed': 2.6},
#                      {'apparentTemperature': 15.98,
#                       'cloudCover': 0,
#                       'dewPoint': 13.46,
#                       'humidity': 0.9,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 15.98,
#                       'time': 1233655200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 7,
#                       'windGust': 8.94,
#                       'windSpeed': 1.99},
#                      {'apparentTemperature': 15.47,
#                       'cloudCover': 0,
#                       'dewPoint': 12.54,
#                       'humidity': 0.88,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 15.47,
#                       'time': 1233658800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 335,
#                       'windGust': 7.51,
#                       'windSpeed': 1.84},
#                      {'apparentTemperature': 14.9,
#                       'cloudCover': 0,
#                       'dewPoint': 12.02,
#                       'humidity': 0.88,
#                       'icon': 'clear-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 14.9,
#                       'time': 1233662400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 307,
#                       'windGust': 6.77,
#                       'windSpeed': 1.13},
#                      {'apparentTemperature': 14.35,
#                       'cloudCover': 0,
#                       'dewPoint': 11.04,
#                       'humidity': 0.86,
#                       'icon': 'clear-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 14.35,
#                       'time': 1233666000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 309,
#                       'windGust': 5.03,
#                       'windSpeed': 0.29},
#                      {'apparentTemperature': 15.97,
#                       'cloudCover': 0,
#                       'dewPoint': 14.08,
#                       'humidity': 0.92,
#                       'icon': 'clear-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 15.97,
#                       'time': 1233669600,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 11,
#                       'windGust': 4.95,
#                       'windSpeed': 0.21},
#                      {'apparentTemperature': 21.36,
#                       'cloudCover': 0,
#                       'dewPoint': 14.83,
#                       'humidity': 0.75,
#                       'icon': 'clear-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 21.36,
#                       'time': 1233673200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 242,
#                       'windGust': 5.56,
#                       'windSpeed': 0.98},
#                      {'apparentTemperature': 23.9,
#                       'cloudCover': 0.19,
#                       'dewPoint': 15.64,
#                       'humidity': 0.7,
#                       'icon': 'clear-day',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Clear',
#                       'temperature': 23.9,
#                       'time': 1233676800,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 220,
#                       'windGust': 7.66,
#                       'windSpeed': 1.16},
#                      {'apparentTemperature': 24.76,
#                       'cloudCover': 1,
#                       'dewPoint': 17.16,
#                       'humidity': 0.72,
#                       'icon': 'cloudy',
#                       'precipAccumulation': 0.01,
#                       'precipIntensity': 0.0008,
#                       'precipProbability': 0.22,
#                       'precipType': 'snow',
#                       'summary': 'Overcast',
#                       'temperature': 24.76,
#                       'time': 1233680400,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 250,
#                       'windGust': 10.62,
#                       'windSpeed': 2.34},
#                      {'apparentTemperature': 24.5,
#                       'cloudCover': 1,
#                       'dewPoint': 19.74,
#                       'humidity': 0.82,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 24.5,
#                       'time': 1233684000,
#                       'uvIndex': 3,
#                       'visibility': 10,
#                       'windBearing': 247,
#                       'windGust': 11.44,
#                       'windSpeed': 2.93},
#                      {'apparentTemperature': 18.19,
#                       'cloudCover': 1,
#                       'dewPoint': 20.87,
#                       'humidity': 0.88,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 24.02,
#                       'time': 1233687600,
#                       'uvIndex': 3,
#                       'visibility': 5.39,
#                       'windBearing': 247,
#                       'windGust': 14.98,
#                       'windSpeed': 4.55},
#                      {'apparentTemperature': 20.27,
#                       'cloudCover': 1,
#                       'dewPoint': 23.15,
#                       'humidity': 0.93,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 24.95,
#                       'time': 1233691200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 245,
#                       'windGust': 13.63,
#                       'windSpeed': 3.73},
#                      {'apparentTemperature': 18.77,
#                       'cloudCover': 1,
#                       'dewPoint': 20.4,
#                       'humidity': 0.83,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 24.79,
#                       'time': 1233694800,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 253,
#                       'windGust': 15.28,
#                       'windSpeed': 4.85},
#                      {'apparentTemperature': 23.71,
#                       'cloudCover': 1,
#                       'dewPoint': 21.76,
#                       'humidity': 0.92,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 23.71,
#                       'time': 1233698400,
#                       'uvIndex': 0,
#                       'visibility': 6.1,
#                       'windBearing': 220,
#                       'windGust': 11.87,
#                       'windSpeed': 2.16},
#                      {'apparentTemperature': 16.54,
#                       'cloudCover': 1,
#                       'dewPoint': 21.45,
#                       'humidity': 1,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 21.45,
#                       'time': 1233702000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 264,
#                       'windGust': 11.22,
#                       'windSpeed': 3.53},
#                      {'apparentTemperature': 15.39,
#                       'cloudCover': 1,
#                       'dewPoint': 20.01,
#                       'humidity': 0.99,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 20.14,
#                       'time': 1233705600,
#                       'uvIndex': 0,
#                       'visibility': 7.29,
#                       'windBearing': 271,
#                       'windGust': 14.96,
#                       'windSpeed': 3.31},
#                      {'apparentTemperature': 10.14,
#                       'cloudCover': 1,
#                       'dewPoint': 11.59,
#                       'humidity': 0.85,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 15.38,
#                       'time': 1233709200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 305,
#                       'windGust': 16.03,
#                       'windSpeed': 3.21},
#                      {'apparentTemperature': 4.47,
#                       'cloudCover': 0.75,
#                       'dewPoint': 6.65,
#                       'humidity': 0.8,
#                       'icon': 'partly-cloudy-night',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Mostly Cloudy',
#                       'temperature': 11.6,
#                       'time': 1233712800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 278,
#                       'windGust': 14.28,
#                       'windSpeed': 4.03},
#                      {'apparentTemperature': -1.54,
#                       'cloudCover': 1,
#                       'dewPoint': 4.19,
#                       'humidity': 0.86,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 7.42,
#                       'time': 1233716400,
#                       'uvIndex': 0,
#                       'visibility': 8.62,
#                       'windBearing': 311,
#                       'windGust': 14.57,
#                       'windSpeed': 4.81},
#                      {'apparentTemperature': 4.38,
#                       'cloudCover': 1,
#                       'dewPoint': 1.85,
#                       'humidity': 0.89,
#                       'icon': 'cloudy',
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'summary': 'Overcast',
#                       'temperature': 4.38,
#                       'time': 1233720000,
#                       'uvIndex': 0,
#                       'visibility': 8.62,
#                       'windBearing': 328,
#                       'windGust': 14.15,
#                       'windSpeed': 2.51}],
#             'icon': 'cloudy',
#             'summary': 'Overcast starting in the afternoon.'},
#  'latitude': 35.611764,
#  'longitude': -83.489545,
#  'offset': -5,
#  'timezone': 'America/New_York'}

# %%
# Create range of dates to use in loop when going through API

dates = pd.date_range(start='2009-01-01', end='2018-12-31', freq='3d')

print(dates)
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-04', '2009-01-07', '2009-01-10',
#                '2009-01-13', '2009-01-16', '2009-01-19', '2009-01-22',
#                '2009-01-25', '2009-01-28',
#                ...
#                '2018-12-04', '2018-12-07', '2018-12-10', '2018-12-13',
#                '2018-12-16', '2018-12-19', '2018-12-22', '2018-12-25',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', length=1218, freq='3D')

# %%
# Create list of dates in the format needed for the API calls

url_dates = []
reg_dates = []
months = []
years = []

for x in dates:
    date_parts = datetime.datetime.strptime((str(x).split(' ', 1)[0]), "%Y-%m-%d")
    # month number
    months.append(date_parts.month)
    years.append(date_parts.year)
    reg_dates.append((str(x).split(' ', 1)[0]))
    url_dates.append((str(x).split(' ', 1)[0]) + "T12:00:00")
    
print(url_dates)
# Out:
# ['2009-01-01T12:00:00', '2009-01-04T12:00:00', '2009-01-07T12:00:00', '2009-01-10T12:00:00', '2009-01-13T12:00:00', '2009-01-16T12:00:00', '2009-01-19T12:00:00', '2009-01-22T12:00:00', '2009-01-25T12:00:00', '2009-01-28T12:00:00', '2009-01-31T12:00:00', '2009-02-03T12:00:00', '2009-02-06T12:00:00', '2009-02-09T12:00:00', '2009-02-12T12:00:00', '2009-02-15T12:00:00', '2009-02-18T12:00:00', '2009-02-21T12:00:00', '2009-02-24T12:00:00', '2009-02-27T12:00:00', '2009-03-02T12:00:00', '2009-03-05T12:00:00', '2009-03-08T12:00:00', '2009-03-11T12:00:00', '2009-03-14T12:00:00', '2009-03-17T12:00:00', '2009-03-20T12:00:00', '2009-03-23T12:00:00', '2009-03-26T12:00:00', '2009-03-29T12:00:00', '2009-04-01T12:00:00', '2009-04-04T12:00:00', '2009-04-07T12:00:00', '2009-04-10T12:00:00', '2009-04-13T12:00:00', '2009-04-16T12:00:00', '2009-04-19T12:00:00', '2009-04-22T12:00:00', '2009-04-25T12:00:00', '2009-04-28T12:00:00', '2009-05-01T12:00:00', '2009-05-04T12:00:00', '2009-05-07T12:00:00', '2009-05-10T12:00:00', '2009-05-13T12:00:00', '2009-05-16T12:00:00', '2009-05-19T12:00:00', '2009-05-22T12:00:00', '2009-05-25T12:00:00', '2009-05-28T12:00:00', '2009-05-31T12:00:00', '2009-06-03T12:00:00', '2009-06-06T12:00:00', '2009-06-09T12:00:00', '2009-06-12T12:00:00', '2009-06-15T12:00:00', '2009-06-18T12:00:00', '2009-06-21T12:00:00', '2009-06-24T12:00:00', '2009-06-27T12:00:00', '2009-06-30T12:00:00', '2009-07-03T12:00:00', '2009-07-06T12:00:00', '2009-07-09T12:00:00', '2009-07-12T12:00:00', '2009-07-15T12:00:00', '2009-07-18T12:00:00', '2009-07-21T12:00:00', '2009-07-24T12:00:00', '2009-07-27T12:00:00', '2009-07-30T12:00:00', '2009-08-02T12:00:00', '2009-08-05T12:00:00', '2009-08-08T12:00:00', '2009-08-11T12:00:00', '2009-08-14T12:00:00', '2009-08-17T12:00:00', '2009-08-20T12:00:00', '2009-08-23T12:00:00', '2009-08-26T12:00:00', '2009-08-29T12:00:00', '2009-09-01T12:00:00', '2009-09-04T12:00:00', '2009-09-07T12:00:00', '2009-09-10T12:00:00', '2009-09-13T12:00:00', '2009-09-16T12:00:00', '2009-09-19T12:00:00', '2009-09-22T12:00:00', '2009-09-25T12:00:00', '2009-09-28T12:00:00', '2009-10-01T12:00:00', '2009-10-04T12:00:00', '2009-10-07T12:00:00', '2009-10-10T12:00:00', '2009-10-13T12:00:00', '2009-10-16T12:00:00', '2009-10-19T12:00:00', '2009-10-22T12:00:00', '2009-10-25T12:00:00', '2009-10-28T12:00:00', '2009-10-31T12:00:00', '2009-11-03T12:00:00', '2009-11-06T12:00:00', '2009-11-09T12:00:00', '2009-11-12T12:00:00', '2009-11-15T12:00:00', '2009-11-18T12:00:00', '2009-11-21T12:00:00', '2009-11-24T12:00:00', '2009-11-27T12:00:00', '2009-11-30T12:00:00', '2009-12-03T12:00:00', '2009-12-06T12:00:00', '2009-12-09T12:00:00', '2009-12-12T12:00:00', '2009-12-15T12:00:00', '2009-12-18T12:00:00', '2009-12-21T12:00:00', '2009-12-24T12:00:00', '2009-12-27T12:00:00', '2009-12-30T12:00:00', '2010-01-02T12:00:00', '2010-01-05T12:00:00', '2010-01-08T12:00:00', '2010-01-11T12:00:00', '2010-01-14T12:00:00', '2010-01-17T12:00:00', '2010-01-20T12:00:00', '2010-01-23T12:00:00', '2010-01-26T12:00:00', '2010-01-29T12:00:00', '2010-02-01T12:00:00', '2010-02-04T12:00:00', '2010-02-07T12:00:00', '2010-02-10T12:00:00', '2010-02-13T12:00:00', '2010-02-16T12:00:00', '2010-02-19T12:00:00', '2010-02-22T12:00:00', '2010-02-25T12:00:00', '2010-02-28T12:00:00', '2010-03-03T12:00:00', '2010-03-06T12:00:00', '2010-03-09T12:00:00', '2010-03-12T12:00:00', '2010-03-15T12:00:00', '2010-03-18T12:00:00', '2010-03-21T12:00:00', '2010-03-24T12:00:00', '2010-03-27T12:00:00', '2010-03-30T12:00:00', '2010-04-02T12:00:00', '2010-04-05T12:00:00', '2010-04-08T12:00:00', '2010-04-11T12:00:00', '2010-04-14T12:00:00', '2010-04-17T12:00:00', '2010-04-20T12:00:00', '2010-04-23T12:00:00', '2010-04-26T12:00:00', '2010-04-29T12:00:00', '2010-05-02T12:00:00', '2010-05-05T12:00:00', '2010-05-08T12:00:00', '2010-05-11T12:00:00', '2010-05-14T12:00:00', '2010-05-17T12:00:00', '2010-05-20T12:00:00', '2010-05-23T12:00:00', '2010-05-26T12:00:00', '2010-05-29T12:00:00', '2010-06-01T12:00:00', '2010-06-04T12:00:00 ...

# %%
# Make dataframe of dates, api dates, years, and months
date_df = pd.DataFrame({"date" : reg_dates,
                        "url_date" : url_dates,
                        "year" : years,
                        "month" : months})

date_df.head()
# Out:
#          date             url_date  year  month
# 0  2009-01-01  2009-01-01T12:00:00  2009      1
# 1  2009-01-04  2009-01-04T12:00:00  2009      1
# 2  2009-01-07  2009-01-07T12:00:00  2009      1
# 3  2009-01-10  2009-01-10T12:00:00  2009      1
# 4  2009-01-13  2009-01-13T12:00:00  2009      1

# %%
base_url = "https://api.darksky.net/forecast/207521500b0c1207a0cd6d1181bf4ce1/" 

parks = park_df["Park"]
lat = park_df["Lat"]
lng = park_df["Lng"]



# Empty lists for new dataframe
df_dates = []
df_months = []
df_years = []
df_parks = []
temps = []

for x in range(len(parks)):
    coord = str(lat[x]) + "," + str(lng[x])
    
    print("Currently gathering temperatures for " + parks[x])
    
    for z in range(len(url_dates)):
        try:
            weather_url = base_url + coord + "," + url_dates[z]
            response = requests.get(weather_url).json()
            temp = response["daily"]["data"][0]["temperatureHigh"]
            temps.append(temp)
            df_dates.append(reg_dates[z])
            df_months.append(months[z])
            df_years.append(years[z])
            df_parks.append(parks[x])
#           print(parks[x] + " temperature (" + reg_dates[z] + "): " + str(temp))
        except KeyError:
            print("Record not found, skipping.")
# Out:
# Currently gathering temperatures for Great Smoky Mountains National Park
# Currently gathering temperatures for Grand Canyon National Park
# Record not found, skipping.
# Currently gathering temperatures for Yosemite National Park
# Record not found, skipping.
# Currently gathering temperatures for Rocky Mountain National Park
# Record not found, skipping.
# Currently gathering temperatures for Zion National Park
# Record not found, skipping.
# Currently gathering temperatures for Yellowstone National Park
# Record not found, skipping.
# Currently gathering temperatures for Olympic National Park
# Record not found, skipping.
# Currently gathering temperatures for Acadia National Park
# Currently gathering temperatures for Grand Teton National Park
# Record not found, skipping.
# Currently gathering temperatures for Glacier National Park
# Record not found, skipping.

# %%
final_df = pd.DataFrame({"Park" : df_parks,
                        "Date" : df_dates,
                        "Year" : df_years,
                        "Month" : df_months,
                        "Temp" : temps})


final_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1590b32338a3> in <module>
# ----> 1 final_df = pd.DataFrame({"Park" : df_parks,
#       2                         "Date" : df_dates,
#       3                         "Year" : df_years,
#       4                         "Month" : df_months,
#       5                         "Temp" : temps})
#
# NameError: name 'df_parks' is not defined

# %%
final_df.to_csv("final_df.csv", index = False, header = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6045af6c97c4> in <module>
# ----> 1 final_df.to_csv("final_df.csv", index = False, header = True)
#
# NameError: name 'final_df' is not defined

# %%
avg_by_month_df = final_df.groupby(["Park", "Year", "Month"]).mean()
avg_by_month_df = avg_by_month_df.reset_index()
avg_by_month_df

#avg_by_month_df.to_csv("avg_by_month.csv", index = False, header = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5bee9d8008a1> in <module>
# ----> 1 avg_by_month_df = final_df.groupby(["Park", "Year", "Month"]).mean()
#       2 avg_by_month_df = avg_by_month_df.reset_index()
#       3 avg_by_month_df
#       4
#       5 #avg_by_month_df.to_csv("avg_by_month.csv", index = False, header = True)
#
# NameError: name 'final_df' is not defined

# %%
avg_by_year_df = final_df.groupby(["Park", "Year"]).mean()
del avg_by_year_df["Month"]
avg_by_year_df = avg_by_year_df.reset_index()
avg_by_year_df

avg_by_year_df.to_csv("avg_by_year.csv", index = False, header = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2b0765b1032d> in <module>
# ----> 1 avg_by_year_df = final_df.groupby(["Park", "Year"]).mean()
#       2 del avg_by_year_df["Month"]
#       3 avg_by_year_df = avg_by_year_df.reset_index()
#       4 avg_by_year_df
#       5
#
# NameError: name 'final_df' is not defined

# %%
avg_by_year_all_df = final_df.groupby(["Year"]).mean()
del avg_by_year_all_df["Month"]
avg_by_year_all_df = avg_by_year_all_df.reset_index()
avg_by_year_all_df

avg_by_year_all_df.to_csv("avg_by_year_all_df.csv", index = False, header = True)

# %%
avg_by_year_month_all_df = final_df.groupby(["Year","Month"]).mean()
avg_by_year_month_all_df = avg_by_year_month_all_df.reset_index()
avg_by_year_month_all_df

avg_by_year_month_all_df.to_csv("avg_by_year_month_all_df.csv", index = False, header = True)

# %% [markdown]
# ### Final Data Frame for Weather: including lat/long

# %%
file = "avg_by_month.csv"
new_df = pd.read_csv(file)
new_df
# Out:
#                       Park  Year  Month       Temp
# 0     Acadia National Park  2009      1  21.501818
# 1     Acadia National Park  2009      2  28.770000
# 2     Acadia National Park  2009      3  32.956000
# 3     Acadia National Park  2009      4  45.278000
# 4     Acadia National Park  2009      5  54.897273
# 5     Acadia National Park  2009      6  59.150000
# 6     Acadia National Park  2009      7  62.654000
# 7     Acadia National Park  2009      8  68.203000
# 8     Acadia National Park  2009      9  59.403000
# 9     Acadia National Park  2009     10  48.867273
# 10    Acadia National Park  2009     11  46.557000
# 11    Acadia National Park  2009     12  31.283000
# 12    Acadia National Park  2010      1  25.784000
# 13    Acadia National Park  2010      2  30.441000
# 14    Acadia National Park  2010      3  40.680000
# 15    Acadia National Park  2010      4  49.766000
# 16    Acadia National Park  2010      5  58.117000
# 17    Acadia National Park  2010      6  63.311000
# 18    Acadia National Park  2010      7  69.310909
# 19    Acadia National Park  2010      8  69.672000
# 20    Acadia National Park  2010      9  62.881000
# 21    Acadia National Park  2010     10  54.116000
# 22    Acadia National Park  2010     11  41.287000
# 23    Acadia National Park  2010     12  30.597273
# 24    Acadia National Park  2011      1  24.576000
# 25    Acadia National Park  2011      2  28.726667
# 26    Acadia National Park  2011      3  34.337273
# 27    Acadia National Park  2011      4  46.317000
# 28    Acadia National Park  2011      5  53.547000
# 29    Acadia National Park  2011      6  58.630000
# ...                    ...   ...    ...        ...
# 1170    Zion National Park  2016      7  85.500000
# 1171    Zion National Park  2016      8  77.825455
# 1172    Zion National Park  2016      9  71.926000
# 1173    Zion National Park  2016     10  64.921000
# 1174    Zion National Park  2016     11  54.268000
# 1175    Zion National Park  2016     12  40.819000
# 1176    Zion National Park  2017      1  37.969091
# 1177    Zion National Park  2017      2  45.505556
# 1178    Zion National Park  2017      3  58.745000
# 1179    Zion National Park  2017      4  57.193000
# 1180    Zion National Park  2017      5  66.784545
# 1181    Zion National Park  2017      6  83.309000
# 1182    Zion National Park  2017      7  85.521000
# 1183    Zion National Park  2017      8  82.093000
# 1184    Zion National Park  2017      9  72.595000
# 1185    Zion National Park  2017     10  66.891818
# 1186    Zion National Park  2017     11  57.505000
# 1187    Zion National Park  2017     12  48.038000
# 1188    Zion National Park  2018      1  46.546000
# 1189    Zion National Park  2018      2  44.132000
# 1190    Zion National Park  2018      3  50.607000
# 1191    Zion National Park  2018      4  62.518000
# 1192    Zion National Park  2018      5  69.571000
# 1193    Zion National Park  2018      6  82.373000
# 1194    Zion National Park  2018      7  86.083636
# 1195    Zion National Park  2018      8  82.840000
# 1196    Zion National Park  2018      9  78.094000
# 1197    Zion National Park  2018     10  56.221111
# 1198    Zion National Park  2018     11  50.369000
# 1199    Zion National Park  2018     12  39.346364
#
# [1200 rows x 4 columns]

# %%
new_df["Vistors"] = ""
new_df
# Out:
#                       Park  Year  Month       Temp Vistors
# 0     Acadia National Park  2009      1  21.501818
# 1     Acadia National Park  2009      2  28.770000
# 2     Acadia National Park  2009      3  32.956000
# 3     Acadia National Park  2009      4  45.278000
# 4     Acadia National Park  2009      5  54.897273
# 5     Acadia National Park  2009      6  59.150000
# 6     Acadia National Park  2009      7  62.654000
# 7     Acadia National Park  2009      8  68.203000
# 8     Acadia National Park  2009      9  59.403000
# 9     Acadia National Park  2009     10  48.867273
# 10    Acadia National Park  2009     11  46.557000
# 11    Acadia National Park  2009     12  31.283000
# 12    Acadia National Park  2010      1  25.784000
# 13    Acadia National Park  2010      2  30.441000
# 14    Acadia National Park  2010      3  40.680000
# 15    Acadia National Park  2010      4  49.766000
# 16    Acadia National Park  2010      5  58.117000
# 17    Acadia National Park  2010      6  63.311000
# 18    Acadia National Park  2010      7  69.310909
# 19    Acadia National Park  2010      8  69.672000
# 20    Acadia National Park  2010      9  62.881000
# 21    Acadia National Park  2010     10  54.116000
# 22    Acadia National Park  2010     11  41.287000
# 23    Acadia National Park  2010     12  30.597273
# 24    Acadia National Park  2011      1  24.576000
# 25    Acadia National Park  2011      2  28.726667
# 26    Acadia National Park  2011      3  34.337273
# 27    Acadia National Park  2011      4  46.317000
# 28    Acadia National Park  2011      5  53.547000
# 29    Acadia National Park  2011      6  58.630000
# ...                    ...   ...    ...        ...     ...
# 1170    Zion National Park  2016      7  85.500000
# 1171    Zion National Park  2016      8  77.825455
# 1172    Zion National Park  2016      9  71.926000
# 1173    Zion National Park  2016     10  64.921000
# 1174    Zion National Park  2016     11  54.268000
# 1175    Zion National Park  2016     12  40.819000
# 1176    Zion National Park  2017      1  37.969091
# 1177    Zion National Park  2017      2  45.505556
# 1178    Zion National Park  2017      3  58.745000
# 1179    Zion National Park  2017      4  57.193000
# 1180    Zion National Park  2017      5  66.784545
# 1181    Zion National Park  2017      6  83.309000
# 1182    Zion National Park  2017      7  85.521000
# 1183    Zion National Park  2017      8  82.093000
# 1184    Zion National Park  2017      9  72.595000
# 1185    Zion National Park  2017     10  66.891818
# 1186    Zion National Park  2017     11  57.505000
# 1187    Zion National Park  2017     12  48.038000
# 1188    Zion National Park  2018      1  46.546000
# 1189    Zion National Park  2018      2  44.132000
# 1190    Zion National Park  2018      3  50.607000
# 1191    Zion National Park  2018      4  62.518000
# 1192    Zion National Park  2018      5  69.571000
# 1193    Zion National Park  2018      6  82.373000
# 1194    Zion National Park  2018      7  86.083636
# 1195    Zion National Park  2018      8  82.840000
# 1196    Zion National Park  2018      9  78.094000
# 1197    Zion National Park  2018     10  56.221111
# 1198    Zion National Park  2018     11  50.369000
# 1199    Zion National Park  2018     12  39.346364
#
# [1200 rows x 5 columns]

# %%
file = "national_parks.csv"
coords_df = pd.read_csv(file)

coords_df.head()

merged_df = pd.merge(new_df, coords_df, how="inner")

merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e25b4f7ee4c1> in <module>
#       5 coords_df.head()
#       6
# ----> 7 merged_df = pd.merge(new_df, coords_df, how="inner")
#       8
#       9 merged_df
#
# NameError: name 'new_df' is not defined

# %%
merged_df.to_csv("with_coords.csv", index = False, header = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-9f535943f7a0> in <module>
# ----> 1 merged_df.to_csv("with_coords.csv", index = False, header = True)
#
# NameError: name 'merged_df' is not defined
